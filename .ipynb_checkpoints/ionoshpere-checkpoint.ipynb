# %%
import ipympl
import numpy as np
import pandas as pd
from pyod.models.knn import KNN
from pyod.models.auto_encoder import AutoEncoder
from pyod.utils.data import generate_data
from pyod.utils.data import evaluate_print
from pyod.utils.example import visualize
from pyod.models.combination import aom, moa, average, maximization, median, majority_vote 
import scipy.io
#import matplotlib
#matplotlib.use('nbagg')
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt



from sklearn.model_selection import train_test_split
from pyod.utils.utility import standardizer
from keras.callbacks.callbacks import EarlyStopping
from tensorflow.python.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Dropout
from tensorflow.python.keras.models import Model
from mpl_toolkits.mplot3d import axes3d
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Using TensorFlow backend.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
mat = scipy.io.loadmat('cardio.mat')
#mat = scipy.io.loadmat('satellite.mat')
#mat = scipy.io.loadmat('ionosphere.mat')

# %%
epochs = 100

# %%
cb_earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0,
mode='auto', baseline=None, restore_best_weights=False)
#pyod_model.fit(scaler, callbacks=[cb_earlystop])

# %%
Xtemp = mat['X']
ytemp = mat['y']
X = np.array(Xtemp)
y = np.array(ytemp)
print(X.shape)
y = y.reshape(X.shape[0],)
print(y.shape)
# Out:
# (1831, 21)
# (1831,)

# %%
outliers = 0
for i in range(y.shape[0]):
    if(y[i]==1.0):
        outliers+=1;
        
print(outliers)
contam = outliers/y.shape[0]
print(contam)
# Out:
# 176
# 0.0961223375204806

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=20)
x_train2, x_test2, y_train2, y_test2 = train_test_split(X, y, test_size=0.40, random_state=6)
x_train3, x_test3, y_train3, y_test3 = train_test_split(X, y, test_size=0.40, random_state=7)

# %%
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
x_train = StandardScaler().fit_transform(x_train)
x_train = pd.DataFrame(x_train)
x_test = StandardScaler().fit_transform(x_test)
x_test = pd.DataFrame(x_test)

x_train2 = pd.DataFrame(x_train2)
x_test2 = pd.DataFrame(x_test2)
x_train2 = StandardScaler().fit_transform(x_train2)
x_train2 = pd.DataFrame(x_train2)
x_test2 = StandardScaler().fit_transform(x_test2)
x_test2 = pd.DataFrame(x_test2)

x_train3 = pd.DataFrame(x_train3)
x_test3 = pd.DataFrame(x_test3)
x_train3 = StandardScaler().fit_transform(x_train3)
x_train3 = pd.DataFrame(x_train3)
x_test3 = StandardScaler().fit_transform(x_test3)
x_test3 = pd.DataFrame(x_test3)

# %%
x_train_full = x_train.copy()
x_train_full['y']=y_train
x_train_full2 = x_train2.copy()
x_train_full2['y']=y_train2
x_train_full3 = x_train3.copy()
x_train_full3['y']=y_train3

# %%
x_test_full = x_test.copy()
x_test_full['y']=y_test
x_test_full2 = x_test2.copy()
x_test_full2['y']=y_test2
x_test_full3 = x_test3.copy()
x_test_full3['y']=y_test3
#sns.scatterplot(x=0, y=1, hue='y', data=x_test_full);

# %%
pca = PCA(2)
x_pca = pca.fit_transform(x_train)
x_pca = pd.DataFrame(x_pca)
x_pca.columns=['PC1','PC2']

# Plot
fig11, ax11 = plt.subplots()

ax11.scatter(x_pca['PC1'], x_pca['PC2'], c=y_train, alpha=0.8)
ax11.legend()
ax11.set_xlabel('x')
ax11.set_ylabel('y')
# Out:
# No handles with labels found to put in legend.
# Text(0, 0.5, 'y')

# %%
clf1 = AutoEncoder(hidden_neurons =[ 20, 10, 2,  10, 20]
                   ,contamination = contam
                   ,epochs=epochs
                  )

clf1.fit(x_train)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None,
# Epoch 89/100
# 988/988 [==============================] - 0s 123us/step - loss: 1.8164 - val_loss: 1.6428
# Epoch 90/100
# 988/988 [==============================] - 0s 133us/step - loss: 1.8033 - val_loss: 1.6327
# Epoch 91/100
# 988/988 [==============================] - 0s 139us/step - loss: 1.7874 - val_loss: 1.6228
# Epoch 92/100
# 988/988 [==============================] - 0s 140us/step - loss: 1.7836 - val_loss: 1.6129
# Epoch 93/100
# 988/988 [==============================] - 0s 133us/step - loss: 1.7699 - val_loss: 1.6032
# Epoch 94/100
# 988/988 [==============================] - 0s 133us/step - loss: 1.7533 - val_loss: 1.5937
# Epoch 95/100
# 988/988 [==============================] - 0s 136us/step - loss: 1.7468 - val_loss: 1.5844
# Epoch 96/100
# 988/988 [==============================] - 0s 137us/step - loss: 1.7409 - val_loss: 1.5753
# Epoch 97/100
# 988/988 [==============================] - 0s 133us/step - loss: 1.7387 - val_loss: 1.5662
# Epoch 98/100
# 988/988 [==============================] - 0s 129us/step - loss: 1.7278 - val_loss: 1.5574
# Epoch 99/100
# 988/988 [==============================] - 0s 128us/step - loss: 1.7123 - val_loss: 1.5487
# Epoch 100/100
# 988/988 [==============================] - 0s 135us/step - loss: 1.7006 - val_loss: 1.5398
# AutoEncoder(batch_size=32, contamination=0.0961223375204806, dropout_rate=0.2,
#       epochs=100, hidden_activation='relu',
#       hidden_neurons=[20, 10, 2, 10, 20], l2_regularizer=0.1,
#       loss=<function mean_squared_error at 0x000001EE221131F8>,
#       optimizer='adam', output_activation='sigmoid', preprocessing=True,
#       random_state=None, validation_size=0.1, verbose=1)

# %%
# Get the outlier scores for the train data
y_train_scores = clf1.decision_scores_  

# Predict the anomaly scores
y_train_pred = clf1.labels_
y_test_scores = clf1.decision_function(x_test)  # outlier scores
y_train_scores = clf1.decision_scores_  # raw outlier scores
#print(y_test_scores.shape)
y_test_scores = pd.Series(y_test_scores)
y_test_pred = clf1.predict(x_test)


#%matplotlib notebook 
pca = PCA(3)
x_pca = pca.fit_transform(x_test)
x_pca = pd.DataFrame(x_pca)
x_pca.columns=['PC1','PC2','PC3']

fig3 = plt.figure()
ax3 = fig3.add_subplot(111, projection='3d')
ax3.set_zlabel("x_composite_3")

ax3.scatter(x_pca['PC1'], x_pca['PC2'], zs=x_pca['PC3'], s=10, lw=1, label="inliers",c=y_test_pred)# Plot x's for the ground truth outliers
# ax.scatter(x_pca['PC1'],x_pca['PC2'], x_pca['PC3'],
#            lw=3, s=60, marker="x", c=y_test_scores3, label="outliers")
ax3.legend()
ax3.view_init(azim=90,elev=20)
plt.show()

# %%
# evaluate and print the results
print("\nOn Training Data:")
evaluate_print('clf_1', y_train, y_train_scores)
print("\nOn Test Data:")
evaluate_print('clf_1', y_test, y_test_scores)
# Out:
# On Training Data:
# clf_1 ROC:0.9497, precision @ rank n:0.6321
#
# On Test Data:
# clf_1 ROC:0.9556, precision @ rank n:0.6143

# %%
print("Test Data Counts")
unique, counts = np.unique(y_test, return_counts=True)
print(dict(zip(unique, counts)))
print("Predicted Data Counts")
unique, counts = np.unique(y_test_pred, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# Test Data Counts
# {0.0: 663, 1.0: 70}
# Predicted Data Counts
# {0: 663, 1: 70}

# %%
# Plot it!
plt.close()
plt.hist(y_test_scores, bins='auto',density=True)  
plt.title("Histogram for Model Clf1 Anomaly Scores")

plt.show()

# %%
df_test = x_test.copy()
df_test['score'] = y_test_scores
df_test['cluster'] = np.where(df_test['score']<6.2, 0, 1)
print(df_test['cluster'].value_counts())

df_test.groupby('cluster').mean()
# Out:
# 0    658
# 1     75
# Name: cluster, dtype: int64
#                 0         1         2         3         4         5         6  \
# cluster
# 0       -0.010507  0.015515 -0.110546  0.010148 -0.081097 -0.073804 -0.171797
# 1        0.092181 -0.136115  0.969856 -0.089033  0.711494  0.647505  1.507231
#
#                 7         8         9  ...        18        19        20  \
# cluster                                ...
# 0       -0.053728 -0.123002 -0.026002  ...  0.080763 -0.154036  0.065417
# 1        0.471371  1.079134  0.228125  ... -0.708560  1.351410 -0.573927
#
#          y_by_average_score  y_by_average_cluster  y_by_maximization_score  \
# cluster
# 0                 -0.089377              0.059271                 0.603621
# 1                  0.711742              0.386667                 2.340771
#
#          y_by_maximization_cluster  y_by_aom_score  y_by_aom_cluster     score
# cluster
# 0                         0.069909       -0.214603          0.077508  3.780238
# 1                         0.373333        0.223134          0.320000  8.232657
#
# [2 rows x 28 columns]

# %%
clf2 = AutoEncoder(hidden_neurons =[20, 12, 6,  2, 6,  12, 20]
                   ,contamination = contam
                   ,epochs=epochs
                  )
clf2.fit(x_train)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 21)                462
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 21)                462
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                440
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 12)                252
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 6)                 78
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 14
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 2)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 6)                 18
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_16 (Dense)             (None, 12)                84
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 20)                260
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 21)                441
# =================================================================
# Total params: 2,511
# Trainable params: 2,511
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 988 samples, validate on 110 samples
# Epoch 1/100
# 988/988 [==============================] - 1s 681us/step - loss: 62.6486 - val_loss: 45.5102
# Epoch 2/100
# 988/988 [==============================] - 0s 151us/step - loss: 43.8675 - val_loss: 35.7704
# Epoch 3/100
# 988/988 [==============================] - 0s 152us/step - loss: 34.2754 - val_loss: 28.7422
# Epoch 4/100
# 988/988 [==============================] - 0s 159us/step - loss: 27.4535 - val_loss: 23.4737
# Epoch 5/100
# 988/988 [==============================] - 0s 154us/step - loss: 22.6708 - val_loss: 19.4984
# Epoch 6/100
# 988/988 [==============================] - 0s 141us/step - loss: 18.8473 - val_loss: 16.5297
# Epoch 7/100
# 988/988 [==============================] - 0s 141us/step - loss: 16.1228 - val_loss: 14.2691
# Epoch 8/100
# 988/988 [==============================] - 0s 146us/step - loss: 14.0276 - val_loss: 12.5239
# Epoch 9/100
# 988/988 [==============================] - 0s 155us/step - loss: 12.3717 - val_loss: 11.0467
# Epoch 10/100
# 988/988 [==============================] - 0s 151us/step - loss: 10.9973 - val_loss: 9.8963
# Epoch 11/100
# 988/988 [==============================] - 0s 140us/step - loss: 10.0515 - val_loss: 8.9642
# Epoch 12/100
# 988/988 [==============================] - 0s 143us/step - loss: 9.0859 - val_loss: 8.1638
# Epoch 13/100
y_test_pred2 = clf2.predict(x_test2)


pca = PCA(3)
x_pca = pca.fit_transform(x_test2)
x_pca = pd.DataFrame(x_pca)
x_pca.columns=['PC1','PC2','PC3']

fig2 = plt.figure()
ax2 = fig2.add_subplot(111, projection='3d')
ax2.set_zlabel("x_composite_3")

ax2.scatter(x_pca['PC1'], x_pca['PC2'], zs=x_pca['PC3'], s=10, lw=1, label="inliers",c=y_test_pred2)# Plot x's for the ground truth outliers
# ax.scatter(x_pca['PC1'],x_pca['PC2'], x_pca['PC3'],
#            lw=3, s=60, marker="x", c=y_test_scores3, label="outliers")
ax2.legend()
ax2.view_init(azim=-160,elev=36)
plt.show()

# %%
# evaluate and print the results
print("\nOn Training Data:")
evaluate_print('clf_2', y_train2, y_train_scores2)
print("\nOn Test Data:")
evaluate_print('clf_2', y_test2, y_test_scores2)
# Out:
# On Training Data:
# clf_2 ROC:0.5181, precision @ rank n:0.0833
#
# On Test Data:
# clf_2 ROC:0.9506, precision @ rank n:0.625

# %%
print("Test Data Counts")
unique, counts = np.unique(y_test2, return_counts=True)
print(dict(zip(unique, counts)))
print("Predicted Data Counts")
unique, counts = np.unique(y_test_pred2, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# Test Data Counts
# {0.0: 653, 1.0: 80}
# Predicted Data Counts
# {0: 664, 1: 69}

# %%
plt.hist(y_test_scores2, bins='auto')  
plt.title("Histogram for Model Clf2 Anomaly Scores")
plt.show()

# %%
# visualize('clf_2', x_train, y_train, x_test, y_test, y_train_pred,
#           y_test_pred, show_figure=True, save_figure=False)

# %%
df_test2 = x_test2.copy()
df_test2['score'] = y_test_scores2
df_test2['cluster'] = np.where(df_test2['score']<6.5, 0, 1)
print(df_test2['cluster'].value_counts())

df_test2.groupby('cluster').mean()
# Out:
# 0    672
# 1     61
# Name: cluster, dtype: int64
#                 0         1         2         3         4         5         6  \
# cluster
# 0       -0.003891  0.024179 -0.113358  0.014744 -0.078918 -0.052124 -0.151317
# 1        0.042868 -0.266369  1.248793 -0.162431  0.869392  0.574217  1.666963
#
#                 7         8         9  ...        12        13        14  \
# cluster                                ...
# 0       -0.037526 -0.102513 -0.021912  ...  0.065852 -0.078532 -0.076467
# 1        0.413396  1.129319  0.241388  ... -0.725454  0.865140  0.842392
#
#                15        16        17        18        19        20     score
# cluster
# 0       -0.043990  0.102771  0.100581  0.087825 -0.145523  0.064817  3.808101
# 1        0.484611 -1.132160 -1.108038 -0.967518  1.603141 -0.714048  8.656406
#
# [2 rows x 22 columns]

# %%
# Step 1: Build the model
clf3 = AutoEncoder(hidden_neurons =[
  #  100, 50,
    25, 1, 25
  #  , 50, 100
]
                   ,contamination = contam
                   ,epochs=epochs
                  )
clf3.fit(x_train)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 21)                462
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 21)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 21)                462
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 21)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 25)                550
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 26
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1)                 0
# _________________________________________________________________
# dense_23 (Dense)             (None, 25)                50
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 21)                546
# =================================================================
# Total params: 2,096
# Trainable params: 2,096
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on
# 988/988 [==============================] - 0s 122us/step - loss: 1.9168 - val_loss: 2.0537
# Epoch 95/100
# 988/988 [==============================] - 0s 113us/step - loss: 1.9034 - val_loss: 2.0416
# Epoch 96/100
# 988/988 [==============================] - 0s 106us/step - loss: 1.9275 - val_loss: 2.0307
# Epoch 97/100
# 988/988 [==============================] - 0s 105us/step - loss: 1.8790 - val_loss: 2.0189
# Epoch 98/100
# 988/988 [==============================] - 0s 108us/step - loss: 1.8849 - val_loss: 2.0075
# Epoch 99/100
# 988/988 [==============================] - 0s 115us/step - loss: 1.8560 - val_loss: 1.9961
# Epoch 100/100
# 988/988 [==============================] - 0s 115us/step - loss: 1.8353 - val_loss: 1.9852
# AutoEncoder(batch_size=32, contamination=0.0961223375204806, dropout_rate=0.2,
#       epochs=100, hidden_activation='relu', hidden_neurons=[25, 1, 25],
#       l2_regularizer=0.1,
#       loss=<function mean_squared_error at 0x000001EE221131F8>,
#       optimizer='adam', output_activation='sigmoid', preprocessing=True,
#       random_state=None, validation_size=0.1, verbose=1)

# %%
# Predict the anomaly scores
y_train_pred3 = clf3.labels_
y_test_scores3 = clf3.decision_function(x_test3)
#print(y_test_scores.shape)
y_test_scores3 = pd.Series(y_test_scores3)
y_train_scores3 = clf3.decision_scores_  # raw outlier scores
y_test_pred3 = clf3.predict(x_test3)


pca = PCA(3)
x_pca = pca.fit_transform(x_test3)
x_pca = pd.DataFrame(x_pca)
x_pca.columns=['PC1','PC2','PC3']
plt.close()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel("x_composite_3")

ax.scatter(x_pca['PC1'], x_pca['PC2'], zs=x_pca['PC3'], s=10, lw=1, label='Score',c=y_test_pred3)# Plot x's for the ground truth outliers
# ax.scatter(x_pca['PC1'],x_pca['PC2'], x_pca['PC3'],
#            lw=3, s=60, marker="x", c=y_test_scores3, label="outliers")
ax.legend()
ax.view_init(azim=90,elev=20)
plt.show()

# %%
# evaluate and print the results
print("\nOn Training Data:")
evaluate_print('clf_3', y_train3, y_train_scores3)
print("\nOn Test Data:")
evaluate_print('clf_3', y_test3, y_test_scores3)
# Out:
# On Training Data:
# clf_3 ROC:0.5489, precision @ rank n:0.1226
#
# On Test Data:
# clf_3 ROC:0.9562, precision @ rank n:0.6143

# %%
print("Test Data Counts")
unique, counts = np.unique(y_test3, return_counts=True)
print(dict(zip(unique, counts)))
print("Predicted Data Counts")
unique, counts = np.unique(y_test_pred3, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# Test Data Counts
# {0.0: 663, 1.0: 70}
# Predicted Data Counts
# {0: 668, 1: 65}

# %%
# Step 2: Determine the cut point
plt.hist(y_test_scores3, bins='auto')  
plt.title("Histogram with Model Clf3 Anomaly Scores")
plt.show()

# %%
df_test3 = x_test3.copy()
df_test3['score'] = y_test_scores3
df_test3['cluster'] = np.where(df_test3['score']<6.2, 0, 1)
print(df_test3['cluster'].value_counts())

df_test3.groupby('cluster').mean()
# Out:
# 0    664
# 1     69
# Name: cluster, dtype: int64
#                 0         1         2         3         4         5         6  \
# cluster
# 0        0.003372  0.023020 -0.104762  0.020896 -0.075981 -0.063649 -0.157034
# 1       -0.032454 -0.221526  1.008145 -0.201089  0.731176  0.612508  1.511165
#
#                 7         8         9  ...        12        13        14  \
# cluster                                ...
# 0       -0.047504 -0.105727 -0.038112  ...  0.067974 -0.069093 -0.070004
# 1        0.457138  1.017432  0.366757  ... -0.654126  0.664892  0.673664
#
#                15        16        17        18        19        20     score
# cluster
# 0       -0.058406  0.115164  0.104774  0.085673 -0.162442  0.056530  3.799831
# 1        0.562052 -1.108248 -1.008257 -0.824450  1.563205 -0.544002  8.357181
#
# [2 rows x 22 columns]

# %%
# Put all the predictions in a data frame
from pyod.models.combination import aom, moa, average, maximization

# Put all the predictions in a data frame
train_scores = pd.DataFrame({'clf1': clf1.decision_scores_,
                             'clf2': clf2.decision_scores_,
                             'clf3': clf3.decision_scores_
                            })

test_scores  = pd.DataFrame({'clf1': clf1.decision_function(x_test),
                             'clf2': clf2.decision_function(x_test2),
                             'clf3': clf3.decision_function(x_test3) 
                            })

# %%
# Although we did standardization before, it was for the variables.
# Now we do the standardization for the decision scores
train_scores_norm, test_scores_norm = standardizer(train_scores,test_scores)

# %%
# Combination by average
y_by_average = average(test_scores_norm)
  

  
plt.hist(y_by_average, bins='auto')  # arguments are passed to np.histogram
plt.title("Combination by average")
plt.show()

# %%
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# x, y = np.random.rand(2, 100) * 4

# hist, xedges, yedges = np.histogram2d(x_test[0], y_by_maximization, bins=10, range=[[-2, 2.5], [-2, 2.5]])

# # Construct arrays for the anchor positions of the 16 bars.
# xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing="ij")
# xpos = xpos.ravel()
# ypos = ypos.ravel()
# zpos = 0

# # Construct arrays with the dimensions for the 16 bars.
# dx = dy = 0.5 * np.ones_like(zpos)
# dz = hist.ravel()

# ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')
# ax.view_init(azim=-220,elev=36)
# plt.show()

# %%
df_test = pd.DataFrame(x_test)
df_test['y_by_average_score'] = y_by_average
df_test['y_by_average_cluster'] = np.where(df_test['y_by_average_score']<0.8, 0, 1)
print(df_test['y_by_average_cluster'].value_counts())



df_test.groupby('y_by_average_cluster').mean()
# Out:
# 0    665
# 1     68
# Name: y_by_average_cluster, dtype: int64
#                              0         1         2         3         4  \
# y_by_average_cluster
# 0                     0.026846  0.014998 -0.087317  0.004542 -0.057205
# 1                    -0.262543 -0.146675  0.853911 -0.044414  0.559427
#
#                              5         6         7         8         9  ...  \
# y_by_average_cluster                                                    ...
# 0                    -0.073804 -0.075428 -0.017705 -0.046823  0.000766  ...
# 1                     0.721757  0.737643  0.173141  0.457902 -0.007488  ...
#
#                             16        17        18        19        20  \
# y_by_average_cluster
# 0                     0.079303  0.074795  0.068496 -0.089332  0.046864
# 1                    -0.775533 -0.731452 -0.669852  0.873615 -0.458304
#
#                       y_by_average_score  y_by_maximization_score  \
# y_by_average_cluster
# 0                              -0.146691                 0.489397
# 1                               1.354703                 3.636642
#
#                       y_by_maximization_cluster  y_by_aom_score  \
# y_by_average_cluster
# 0                                      0.016541       -0.253161
# 1                                      0.735294        0.645266
#
#                       y_by_aom_cluster
# y_by_average_cluster
# 0                             0.031579
# 1                             0.514706
#
# [2 rows x 26 columns]

# %%
# Combination by max
y_by_maximization = maximization(test_scores_norm)
             

plt.hist(y_by_maximization, bins='auto')  # arguments are passed to np.histogram
plt.title("Combination by max")
plt.show()

df_test = pd.DataFrame(x_test)
df_test['y_by_maximization_score'] = y_by_maximization
df_test['y_by_maximization_cluster'] = np.where(df_test['y_by_maximization_score']<2.2, 0, 1)
print(df_test['y_by_maximization_cluster'].value_counts())

df_test.groupby('y_by_maximization_cluster').mean()
# Out:
# 0    659
# 1     74
# Name: y_by_maximization_cluster, dtype: int64
#                                   0         1         2         3         4  \
# y_by_maximization_cluster
# 0                          0.013102  0.016413 -0.094999  0.006058 -0.044667
# 1                         -0.116678 -0.146168  0.846007 -0.053947  0.397775
#
#                                   5         6         7         8         9  \
# y_by_maximization_cluster
# 0                         -0.073804 -0.105056 -0.018042 -0.037661  0.026880
# 1                          0.657252  0.935570  0.160675  0.335384 -0.239381
#
#                            ...        16        17        18        19  \
# y_by_maximization_cluster  ...
# 0                          ...  0.089636  0.068923  0.068715 -0.102245
# 1                          ... -0.798242 -0.613789 -0.611932  0.910535
#
#                                  20  y_by_average_score  y_by_average_cluster  \
# y_by_maximization_cluster
# 0                          0.047162           -0.143840              0.024279
# 1                         -0.420000            1.207579              0.702703
#
#                            y_by_maximization_score  y_by_aom_score  \
# y_by_maximization_cluster
# 0                                         0.445186       -0.224191
# 1                                         3.775176        0.314435
#
#                            y_by_aom_cluster
# y_by_maximization_cluster
# 0                                  0.051593
# 1                                  0.297297
#
# [2 rows x 26 columns]

# %%
# Combination by aom
y_by_aom = median(test_scores_norm)


plt.hist(y_by_aom, bins='auto')  # arguments are passed to np.histogram
plt.title("Average of Maximum")
plt.show()

df_test = pd.DataFrame(x_test)
df_test['y_by_aom_score'] = y_by_aom
df_test['y_by_aom_cluster'] = np.where(df_test['y_by_aom_score']<0.5, 0, 1)
print(df_test['y_by_aom_cluster'].value_counts())


df_test.groupby('y_by_aom_cluster').mean()
# Out:
# 0    658
# 1     75
# Name: y_by_aom_cluster, dtype: int64
#                          0         1         2         3         4         5  \
# y_by_aom_cluster
# 0                 0.020035  0.008935 -0.040039  0.012426 -0.028602  0.008412
# 1                -0.175770 -0.078393  0.351272 -0.109016  0.250934 -0.073804
#
#                          6        7         8         9  ...        16  \
# y_by_aom_cluster                                         ...
# 0                -0.063466 -0.02201 -0.051907 -0.025904  ...  0.040432
# 1                 0.556807  0.19310  0.455399  0.227266  ... -0.354725
#
#                         17        18        19        20  y_by_average_score  \
# y_by_aom_cluster
# 0                 0.050381  0.045842 -0.054247  0.043075           -0.117092
# 1                -0.442011 -0.402188  0.475924 -0.377913            0.954895
#
#                   y_by_average_cluster  y_by_maximization_score  \
# y_by_aom_cluster
# 0                             0.041033                  0.62823
# 1                             0.546667                  2.12487
#
#                   y_by_maximization_cluster  y_by_aom_score
# y_by_aom_cluster
# 0                                  0.072948       -0.295275
# 1                                  0.346667        0.930894
#
# [2 rows x 26 columns]

# %%
# Out:
# {0: 668, 1: 65}

# %%
# Out:
# {0.0: 663, 1.0: 70}
